# %% [markdown]
# # The Battle of the Neighborhoods - Week 2

# %% [markdown]
# ## Step 1 Explore NYC geographical coordinates dataset

# %% [markdown]
# NYC has a total of 5 boroughs and 306 neighbourhoods. To segment the blocks and explore them, we will necessarily need a dataset that contains the 5 districts and the communities that exist in each borough as well as the latitude and longitude coordinates of each neighbourhood.

# %% [markdown]
# For solving that task we will use data set from sourse [here](https://geo.nyu.edu/catalog/nyu_2451_34572)

# %%
#Step 1.1 - import libraries and install modules
import numpy as np
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import requests 
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
from bs4 import BeautifulSoup
import csv
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
#Step 1.2 - download data
# !wget -q -O 'newyork_data.json' https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
#Step 1.3 - explore the data
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
neighborhoods_data = newyork_data['features']
neighborhoods_data[0]

#Tranform the data into a pandas dataframe
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
neighborhoods = pd.DataFrame(columns=column_names)

#Fill the dataframe
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
#Checking resolts
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
#Step 1.4 - using geopy library to get the latitude and longitude values
neighborhoods.to_csv('BON1_NYC_GEO.csv',index=False)
address = 'New York City, NY'

geolocator = Nominatim(user_agent="Jupyter")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
#Step 1.5 - create a map of New York with neighborhoods superimposed on top
map_NewYork = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_NewYork)  
    
map_NewYork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Part 2 Web scrapping of population and demographics data from Wikipedia
# Web scrapping of population and demographics data from Wikipedia pages using by BeautifulSoup

# %%
#Step 2.1 - web scrapping of population and demographics data from Wikipedia pages using by BeautifulSoup
website_url = requests.get('https://en.wikipedia.org/wiki/Demographics_of_New_York_City').text
soup = BeautifulSoup(website_url,'lxml')
table = soup.find('table',{'class':'wikitable sortable'})

headers = [header.text for header in table.find_all('th')]

table_rows = table.find_all('tr')        
rows = []
for row in table_rows:
   td = row.find_all('td')
   row = [row.text for row in td]
   rows.append(row)

with open('BON2_POPULATION1.csv', 'w') as f:
   writer = csv.writer(f)
   writer.writerow(headers)
   writer.writerows(row for row in rows if row)

# %%
#Step 2.2 - load data from CSV
Pop_data=pd.read_csv('BON2_POPULATION1.csv')
Pop_data
# Out:
#                   New York City's five boroughsvte\n   Jurisdiction\n  \
# 0                                        The Bronx\n      \n  Bronx\n
# 1                                         Brooklyn\n      \n  Kings\n
# 2                                        Manhattan\n   \n  New York\n
# 3                                           Queens\n    \n   Queens\n
# 4                                    Staten Island\n  \n   Richmond\n
# 5                                   City of New York        8,622,698
# 6                                  State of New York       19,849,399
# 7  Sources:[14] and see individual borough articl...              NaN
#
#   Population\n Gross Domestic Product\n Land area\n Density\n   Borough  \
# 0  1,471,160\n                 28.787\n    19,570\n   42.10\n  109.04\n
# 1  2,648,771\n                 63.303\n    23,900\n   70.82\n  183.42\n
# 2  1,664,727\n                629.682\n   378,250\n   22.83\n   59.13\n
# 3  2,358,582\n                 73.842\n    31,310\n  108.53\n  281.09\n
# 4    479,458\n                 11.249\n    23,460\n   58.37\n  151.18\n
# 5      806.863                   93,574      302.64    783.83    28,188
# 6    1,547.116                   78,354      47,214   122,284     416.4
# 7          NaN                      NaN         NaN       NaN       NaN
#
#      County Estimate (2017)[12]  billions(US$)[13]  per capita(US$)  \
# 0  34,653\n            13,231\n                NaN              NaN
# 1  37,137\n            14,649\n                NaN              NaN
# 2  72,033\n            27,826\n                NaN              NaN
# 3  21,460\n             8,354\n                NaN              NaN
# 4   8,112\n             3,132\n                NaN              NaN
# 5  10,947\n                 NaN                NaN              NaN
# 6     159\n                 NaN                NaN              NaN
# 7       NaN                 NaN                NaN              NaN
#
#    square miles  squarekm  persons / sq. mi  persons /sq. km\n
# 0           NaN       NaN               NaN                NaN
# 1           NaN       NaN               NaN                NaN
# 2           NaN       NaN               NaN                NaN
# 3           NaN       NaN               NaN                NaN
# 4           NaN       NaN               NaN                NaN
# 5           NaN       NaN               NaN                NaN
# 6           NaN       NaN               NaN                NaN
# 7           NaN       NaN               NaN                NaN

# %%
#Step 2.3 - remove whitespaces and rename columns
Pop_data.columns = Pop_data.columns.str.replace(' ', '')
Pop_data.columns = Pop_data.columns.str.replace('\'','')
Pop_data
# Out:
#                        NewYorkCitysfiveboroughsvte\n   Jurisdiction\n  \
# 0                                        The Bronx\n      \n  Bronx\n
# 1                                         Brooklyn\n      \n  Kings\n
# 2                                        Manhattan\n   \n  New York\n
# 3                                           Queens\n    \n   Queens\n
# 4                                    Staten Island\n  \n   Richmond\n
# 5                                   City of New York        8,622,698
# 6                                  State of New York       19,849,399
# 7  Sources:[14] and see individual borough articl...              NaN
#
#   Population\n GrossDomesticProduct\n Landarea\n Density\n   Borough  \
# 0  1,471,160\n               28.787\n   19,570\n   42.10\n  109.04\n
# 1  2,648,771\n               63.303\n   23,900\n   70.82\n  183.42\n
# 2  1,664,727\n              629.682\n  378,250\n   22.83\n   59.13\n
# 3  2,358,582\n               73.842\n   31,310\n  108.53\n  281.09\n
# 4    479,458\n               11.249\n   23,460\n   58.37\n  151.18\n
# 5      806.863                 93,574     302.64    783.83    28,188
# 6    1,547.116                 78,354     47,214   122,284     416.4
# 7          NaN                    NaN        NaN       NaN       NaN
#
#      County Estimate(2017)[12]  billions(US$)[13]  percapita(US$)  \
# 0  34,653\n           13,231\n                NaN             NaN
# 1  37,137\n           14,649\n                NaN             NaN
# 2  72,033\n           27,826\n                NaN             NaN
# 3  21,460\n            8,354\n                NaN             NaN
# 4   8,112\n            3,132\n                NaN             NaN
# 5  10,947\n                NaN                NaN             NaN
# 6     159\n                NaN                NaN             NaN
# 7       NaN                NaN                NaN             NaN
#
#    squaremiles  squarekm  persons/sq.mi  persons/sq.km\n
# 0          NaN       NaN            NaN              NaN
# 1          NaN       NaN            NaN              NaN
# 2          NaN       NaN            NaN              NaN
# 3          NaN       NaN            NaN              NaN
# 4          NaN       NaN            NaN              NaN
# 5          NaN       NaN            NaN              NaN
# 6          NaN       NaN            NaN              NaN
# 7          NaN       NaN            NaN              NaN

# %%
Pop_data.rename(columns = {'GrossDomesticProduct\n':'GBP_billions',
                           'Borough':'square_km',
                    'NewYorkCitysfiveboroughsvte\n':'Borough',
                   'Jurisdiction\n':'County',
                   'Population\n':'Estimate_2017',
                    'GrossDomesticProduct\n':'GBP_billions',
                    'Landarea\n':'GBP_per_capita',
                     'Density\n':'square_miles',
                    'County':'persons_sq_mi',
                    'Estimate(2017)[12]':'persons_sq_km'}, inplace=True)
Pop_data
# Out:
#                                              Borough           County  \
# 0                                        The Bronx\n      \n  Bronx\n
# 1                                         Brooklyn\n      \n  Kings\n
# 2                                        Manhattan\n   \n  New York\n
# 3                                           Queens\n    \n   Queens\n
# 4                                    Staten Island\n  \n   Richmond\n
# 5                                   City of New York        8,622,698
# 6                                  State of New York       19,849,399
# 7  Sources:[14] and see individual borough articl...              NaN
#
#   Estimate_2017 GBP_billions GBP_per_capita square_miles square_km  \
# 0   1,471,160\n     28.787\n       19,570\n      42.10\n  109.04\n
# 1   2,648,771\n     63.303\n       23,900\n      70.82\n  183.42\n
# 2   1,664,727\n    629.682\n      378,250\n      22.83\n   59.13\n
# 3   2,358,582\n     73.842\n       31,310\n     108.53\n  281.09\n
# 4     479,458\n     11.249\n       23,460\n      58.37\n  151.18\n
# 5       806.863       93,574         302.64       783.83    28,188
# 6     1,547.116       78,354         47,214      122,284     416.4
# 7           NaN          NaN            NaN          NaN       NaN
#
#   persons_sq_mi persons_sq_km  billions(US$)[13]  percapita(US$)  squaremiles  \
# 0      34,653\n      13,231\n                NaN             NaN          NaN
# 1      37,137\n      14,649\n                NaN             NaN          NaN
# 2      72,033\n      27,826\n                NaN             NaN          NaN
# 3      21,460\n       8,354\n                NaN             NaN          NaN
# 4       8,112\n       3,132\n                NaN             NaN          NaN
# 5      10,947\n           NaN                NaN             NaN          NaN
# 6         159\n           NaN                NaN             NaN          NaN
# 7           NaN           NaN                NaN             NaN          NaN
#
#    squarekm  persons/sq.mi  persons/sq.km\n
# 0       NaN            NaN              NaN
# 1       NaN            NaN              NaN
# 2       NaN            NaN              NaN
# 3       NaN            NaN              NaN
# 4       NaN            NaN              NaN
# 5       NaN            NaN              NaN
# 6       NaN            NaN              NaN
# 7       NaN            NaN              NaN

# %%
#Step 2.4 - replace newline('\n') from each string from left and right sides
Pop_data['Borough']=Pop_data['Borough'].replace(to_replace='\n', value='', regex=True)
Pop_data['County']=Pop_data['County'].replace(to_replace='\n', value='', regex=True)
Pop_data['Estimate_2017']=Pop_data['Estimate_2017'].replace(to_replace='\n', value='', regex=True)
Pop_data['square_miles']=Pop_data['square_miles'].replace(to_replace='\n', value='', regex=True)
Pop_data['square_km']=Pop_data['square_km'].replace(to_replace='\n', value='', regex=True)
Pop_data['persons_sq_mi']=Pop_data['persons_sq_mi'].replace(to_replace='\n', value='', regex=True)
Pop_data['persons_sq_km']=Pop_data['persons_sq_km'].replace(to_replace='\n', value='', regex=True)
Pop_data
# Out:
#                                             Borough       County  \
# 0                                         The Bronx        Bronx
# 1                                          Brooklyn        Kings
# 2                                         Manhattan     New York
# 3                                            Queens       Queens
# 4                                     Staten Island     Richmond
# 5                                  City of New York    8,622,698
# 6                                 State of New York   19,849,399
# 7  Sources:[14] and see individual borough articles          NaN
#
#   Estimate_2017 GBP_billions GBP_per_capita square_miles square_km  \
# 0     1,471,160     28.787\n       19,570\n        42.10    109.04
# 1     2,648,771     63.303\n       23,900\n        70.82    183.42
# 2     1,664,727    629.682\n      378,250\n        22.83     59.13
# 3     2,358,582     73.842\n       31,310\n       108.53    281.09
# 4       479,458     11.249\n       23,460\n        58.37    151.18
# 5       806.863       93,574         302.64       783.83    28,188
# 6     1,547.116       78,354         47,214      122,284     416.4
# 7           NaN          NaN            NaN          NaN       NaN
#
#   persons_sq_mi persons_sq_km  billions(US$)[13]  percapita(US$)  squaremiles  \
# 0        34,653        13,231                NaN             NaN          NaN
# 1        37,137        14,649                NaN             NaN          NaN
# 2        72,033        27,826                NaN             NaN          NaN
# 3        21,460         8,354                NaN             NaN          NaN
# 4         8,112         3,132                NaN             NaN          NaN
# 5        10,947           NaN                NaN             NaN          NaN
# 6           159           NaN                NaN             NaN          NaN
# 7           NaN           NaN                NaN             NaN          NaN
#
#    squarekm  persons/sq.mi  persons/sq.km\n
# 0       NaN            NaN              NaN
# 1       NaN            NaN              NaN
# 2       NaN            NaN              NaN
# 3       NaN            NaN              NaN
# 4       NaN            NaN              NaN
# 5       NaN            NaN              NaN
# 6       NaN            NaN              NaN
# 7       NaN            NaN              NaN

# %%
#Step 2.5 - shift data in the last two rows and remove 'NAN'
Pop_data.loc[5:,['persons_sq_mi','persons_sq_km']] = Pop_data.loc[2:,['persons_sq_mi','persons_sq_km']].shift(1,axis=1)
Pop_data.loc[5:,['square_km','persons_sq_mi']] = Pop_data.loc[2:,['square_km','persons_sq_mi']].shift(1,axis=1)
Pop_data.loc[5:,['square_miles','square_km']] = Pop_data.loc[2:,['square_miles','square_km']].shift(1,axis=1)
Pop_data.loc[5:,['Estimate_2017','square_miles']] = Pop_data.loc[2:,['Estimate_2017','square_miles']].shift(1,axis=1)
Pop_data.loc[5:,['County','Estimate_2017']] = Pop_data.loc[2:,['County','Estimate_2017']].shift(1,axis=1)
Pop_data.loc[5:,['Borough','County']] = Pop_data.loc[2:,['Borough','County']].shift(1,axis=1)
Pop_data
# Out:
#          Borough                                            County  \
# 0      The Bronx                                             Bronx
# 1       Brooklyn                                             Kings
# 2      Manhattan                                          New York
# 3         Queens                                            Queens
# 4  Staten Island                                          Richmond
# 5            NaN                                  City of New York
# 6            NaN                                 State of New York
# 7            NaN  Sources:[14] and see individual borough articles
#
#   Estimate_2017 GBP_billions GBP_per_capita square_miles square_km  \
# 0     1,471,160     28.787\n       19,570\n        42.10    109.04
# 1     2,648,771     63.303\n       23,900\n        70.82    183.42
# 2     1,664,727    629.682\n      378,250\n        22.83     59.13
# 3     2,358,582     73.842\n       31,310\n       108.53    281.09
# 4       479,458     11.249\n       23,460\n        58.37    151.18
# 5     8,622,698       93,574         302.64      806.863    783.83
# 6    19,849,399       78,354         47,214    1,547.116   122,284
# 7           NaN          NaN            NaN          NaN       NaN
#
#   persons_sq_mi persons_sq_km  billions(US$)[13]  percapita(US$)  squaremiles  \
# 0        34,653        13,231                NaN             NaN          NaN
# 1        37,137        14,649                NaN             NaN          NaN
# 2        72,033        27,826                NaN             NaN          NaN
# 3        21,460         8,354                NaN             NaN          NaN
# 4         8,112         3,132                NaN             NaN          NaN
# 5        28,188        10,947                NaN             NaN          NaN
# 6         416.4           159                NaN             NaN          NaN
# 7           NaN           NaN                NaN             NaN          NaN
#
#    squarekm  persons/sq.mi  persons/sq.km\n
# 0       NaN            NaN              NaN
# 1       NaN            NaN              NaN
# 2       NaN            NaN              NaN
# 3       NaN            NaN              NaN
# 4       NaN            NaN              NaN
# 5       NaN            NaN              NaN
# 6       NaN            NaN              NaN
# 7       NaN            NaN              NaN

# %%
#Remove 'NAN
Pop_data = Pop_data.fillna('')
Pop_data
# Out:
#          Borough                                            County  \
# 0      The Bronx                                             Bronx
# 1       Brooklyn                                             Kings
# 2      Manhattan                                          New York
# 3         Queens                                            Queens
# 4  Staten Island                                          Richmond
# 5                                                 City of New York
# 6                                                State of New York
# 7                 Sources:[14] and see individual borough articles
#
#   Estimate_2017 GBP_billions GBP_per_capita square_miles square_km  \
# 0     1,471,160     28.787\n       19,570\n        42.10    109.04
# 1     2,648,771     63.303\n       23,900\n        70.82    183.42
# 2     1,664,727    629.682\n      378,250\n        22.83     59.13
# 3     2,358,582     73.842\n       31,310\n       108.53    281.09
# 4       479,458     11.249\n       23,460\n        58.37    151.18
# 5     8,622,698       93,574         302.64      806.863    783.83
# 6    19,849,399       78,354         47,214    1,547.116   122,284
# 7
#
#   persons_sq_mi persons_sq_km billions(US$)[13] percapita(US$) squaremiles  \
# 0        34,653        13,231
# 1        37,137        14,649
# 2        72,033        27,826
# 3        21,460         8,354
# 4         8,112         3,132
# 5        28,188        10,947
# 6         416.4           159
# 7
#
#   squarekm persons/sq.mi persons/sq.km\n
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#Step 2.6 - drop the last row
i = Pop_data[((Pop_data.County == 'Sources:[14] and see individual borough articles'))].index
Pop_data=Pop_data.drop(i)
Pop_data
# Out:
#          Borough             County Estimate_2017 GBP_billions GBP_per_capita  \
# 0      The Bronx              Bronx     1,471,160     28.787\n       19,570\n
# 1       Brooklyn              Kings     2,648,771     63.303\n       23,900\n
# 2      Manhattan           New York     1,664,727    629.682\n      378,250\n
# 3         Queens             Queens     2,358,582     73.842\n       31,310\n
# 4  Staten Island           Richmond       479,458     11.249\n       23,460\n
# 5                  City of New York     8,622,698       93,574         302.64
# 6                 State of New York    19,849,399       78,354         47,214
#
#   square_miles square_km persons_sq_mi persons_sq_km billions(US$)[13]  \
# 0        42.10    109.04        34,653        13,231
# 1        70.82    183.42        37,137        14,649
# 2        22.83     59.13        72,033        27,826
# 3       108.53    281.09        21,460         8,354
# 4        58.37    151.18         8,112         3,132
# 5      806.863    783.83        28,188        10,947
# 6    1,547.116   122,284         416.4           159
#
#   percapita(US$) squaremiles squarekm persons/sq.mi persons/sq.km\n
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
Pop_data.drop(Pop_data.columns[[9,10,11,12,13,14]], axis=1,inplace=True)
Pop_data
# Out:
#          Borough             County Estimate_2017 GBP_billions GBP_per_capita  \
# 0      The Bronx              Bronx     1,471,160     28.787\n       19,570\n
# 1       Brooklyn              Kings     2,648,771     63.303\n       23,900\n
# 2      Manhattan           New York     1,664,727    629.682\n      378,250\n
# 3         Queens             Queens     2,358,582     73.842\n       31,310\n
# 4  Staten Island           Richmond       479,458     11.249\n       23,460\n
# 5                  City of New York     8,622,698       93,574         302.64
# 6                 State of New York    19,849,399       78,354         47,214
#
#   square_miles square_km persons_sq_mi persons_sq_km
# 0        42.10    109.04        34,653        13,231
# 1        70.82    183.42        37,137        14,649
# 2        22.83     59.13        72,033        27,826
# 3       108.53    281.09        21,460         8,354
# 4        58.37    151.18         8,112         3,132
# 5      806.863    783.83        28,188        10,947
# 6    1,547.116   122,284         416.4           159

# %%
#Step 2.7 - save dataframe as csv file
Pop_data.to_csv('BON2_POPULATION.csv',index=False)

# %% [markdown]
# # Part 3 Explore NYC and its Boroughs Cuisine dataset

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot') 
# install wordcloud
# !conda install -c conda-forge wordcloud==1.4.1 --yes
# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS
print ('Wordcloud is installed and imported!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - wordcloud==1.4.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wordcloud-1.4.1            |           py36_0         324 KB  conda-forge
#
# The following NEW packages will be INSTALLED:
#
#     wordcloud: 1.4.1-py36_0 conda-forge
#
#
# Downloading and Extracting Packages
# wordcloud-1.4.1      | 324 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Wordcloud is installed and imported!

# %%
# Fetch the file
my_file = project.get_file("BON3_NYC_CUISINE.csv")
# Read the CSV data file from the object storage into a pandas DataFrame
my_file.seek(0)
import pandas as pd
NYC_CUISINE=pd.read_csv(my_file)
NYC_CUISINE.drop(NYC_CUISINE.columns[[3,4,5,6,7]], axis=1,inplace=True) 
NYC_CUISINE.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-84ad71be788c> in <module>
#       1 # Fetch the file
# ----> 2 my_file = project.get_file("BON3_NYC_CUISINE.csv")
#       3 # Read the CSV data file from the object storage into a pandas DataFrame
#       4 my_file.seek(0)
#       5 import pandas as pd
#
# NameError: name 'project' is not defined

# %%
print(NYC_CUISINE.Borough.unique())

# %%
NYC_CUISINE['Borough'].value_counts().to_frame()

# %% [markdown]
# # #1. NYC CUISINE

# %%
CUISINE_WC = NYC_CUISINE[['Cuisine']]
CUISINE_WC

# %%
CUISINE_WC.to_csv('CUISINE_WC.txt', sep=',', index=False)
CUISINE_WC1 = open('CUISINE_WC.txt', 'r').read()
stopwords = set(STOPWORDS)

# %%
# instantiate and geberate word cloud object
NYC_CUISINE_WC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)
NYC_CUISINE_WC.generate(CUISINE_WC1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-3bcd77e79281> in <module>
#       3     background_color='white',
#       4     max_words=2000,
# ----> 5     stopwords=stopwords
#       6 )
#       7 NYC_CUISINE_WC.generate(CUISINE_WC1)
#
# NameError: name 'stopwords' is not defined

# %% [markdown]
# # #2. BROOKLYN CUISINE

# %%
Brooklyn_data = NYC_CUISINE[NYC_CUISINE['Borough'] == 'Brooklyn'].reset_index(drop=True)
Brooklyn_data.head()

# %%
BR_CUISINE_WC = Brooklyn_data[['Cuisine']]
BR_CUISINE_WC

# %%
BR_CUISINE_WC.to_csv('BR_CUISINE.txt', sep=',', index=False)

# %%
BR_CUISINE_WC = open('BR_CUISINE.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
BR_CUISINE_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
BR_CUISINE_NYC.generate(BR_CUISINE_WC)

# %%
# display the word cloud
plt.imshow(BR_CUISINE_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()

# %% [markdown]
# # #3. QUEENS CUISINE

# %%
Queens_data = NYC_CUISINE[NYC_CUISINE['Borough'] == 'Queens'].reset_index(drop=True)
Q_CUISINE_WC = Queens_data[['Cuisine']]
Q_CUISINE_WC

# %%
Q_CUISINE_WC.to_csv('Q_CUISINE.txt', sep=',', index=False)
Q_CUISINE_WC = open('Q_CUISINE.txt', 'r').read()
stopwords = set(STOPWORDS)
# instantiate a word cloud object
Q_CUISINE_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
Q_CUISINE_NYC.generate(Q_CUISINE_WC)

# display the word cloud
plt.imshow(Q_CUISINE_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()

# %% [markdown]
# # #4. MANHATTAN CUISINE

# %%
Manhattan_data = NYC_CUISINE[NYC_CUISINE['Borough'] == 'Manhattan'].reset_index(drop=True)
Manhattan_data.head()

# %%
MN_CUISINE_WC = Manhattan_data[['Cuisine']]
MN_CUISINE_WC

# %%
MN_CUISINE_WC.to_csv('MN_CUISINE.txt', sep=',', index=False)

# %%
MN_CUISINE_WC = open('MN_CUISINE.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
MN_CUISINE_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
MN_CUISINE_NYC.generate(MN_CUISINE_WC)

# %%
# display the word cloud
plt.imshow(MN_CUISINE_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()

# %% [markdown]
# # #4. THE BRONX CUISINE

# %%
Bronx_data = NYC_CUISINE[NYC_CUISINE['Borough'] == 'The Bronx'].reset_index(drop=True)
Bronx_data.head()

# %%
BX_CUISINE_WC = Bronx_data[['Cuisine']]
BX_CUISINE_WC

# %%
BX_CUISINE_WC.to_csv('BX_CUISINE.txt', sep=',', index=False)
BX_CUISINE_WC = open('BX_CUISINE.txt', 'r').read()
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
BX_CUISINE_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
BX_CUISINE_NYC.generate(BX_CUISINE_WC)

# %%
# display the word cloud
plt.imshow(BX_CUISINE_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()
